# %%
import hoomd
from cmeutils.sampling import equil_sample, is_equilibrated
# Out:
# Warning on use of the timeseries module: If the inherent timescales of the system are long compared to those being analyzed, this statistical inefficiency may be an underestimate.  The estimate presumes the use of many statistically independent samples.  Tests should be performed to assess whether this condition is satisfied.   Be cautious in the interpretation of the data.
#
# ****** PyMBAR will use 64-bit JAX! *******
# * JAX is currently set to 32-bit bitsize *
# * which is its default.                  *
# *                                        *
# * PyMBAR requires 64-bit mode and WILL   *
# * enable JAX's 64-bit mode when called.  *
# *                                        *
# * This MAY cause problems with other     *
# * Uses of JAX in the same code.          *
# ******************************************

# %%
dir(hoomd.version)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_hoomd',
#  'build_dir',
#  'compile_date',
#  'compile_flags',
#  'cuda_devrt_library',
#  'cuda_include_path',
#  'cxx_compiler',
#  'floating_point_precision',
#  'git_branch',
#  'git_sha1',
#  'gpu_api_version',
#  'gpu_enabled',
#  'gpu_platform',
#  'hpmc_built',
#  'install_dir',
#  'llvm_enabled',
#  'md_built',
#  'metal_built',
#  'mpcd_built',
#  'mpi_enabled',
#  'source_dir',
#  'tbb_enabled',
#  'version']

# %% [markdown]
# ## 25,100-mer

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.genfromtxt(fname='/Users/stephaniemccallum/Desktop/cmelab/scratch/pps-melts/f279afbae7a955945fafb6e14c21a787/log.txt', skip_header=True)
plt.xlabel('time step')
plt.ylabel('energy')

plt.plot(data[500:,0], data[500:,3], linestyle='-', marker='*', label='PE()')

# %%
data = np.genfromtxt(fname='/Users/stephaniemccallum/Desktop/cmelab/scratch/pps-melts/f279afbae7a955945fafb6e14c21a787/log.txt', names=True)
pe = data['mdcomputeThermodynamicQuantitiespotential_energy']
is_equilibrated(pe[500:],threshold_fraction=0.25)
# Out:
# [True, 13663, 1.1033703, 5745.1245]

# %% [markdown]
# ## 50, 50-mers

# %%
data = np.genfromtxt(fname='/Users/stephaniemccallum/Desktop/cmelab/scratch/pps-melts/workspace/3cd661b3ad8700ae4df1fe0a279e93e3/log.txt', names=True)
plt.xlabel('time step')
plt.ylabel('energy')
pe = data['mdcomputeThermodynamicQuantitiespotential_energy']
plt.plot(pe[500:,], linestyle='-', marker='*', label='PE()')

# %%
data = np.genfromtxt(fname='/Users/stephaniemccallum/Desktop/cmelab/scratch/pps-melts/workspace/3cd661b3ad8700ae4df1fe0a279e93e3/log.txt', names=True)
pe = data['mdcomputeThermodynamicQuantitiespotential_energy']
is_equilibrated(pe[500:],threshold_fraction=0.25)
# Out:
# [True, 10692, 1.0149754, 9172.636]
