# %%
import hoomd
print(hoomd.version.version)
# Out:
# 4.8.2

# %%
dir(hoomd.version)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_hoomd',
#  'build_dir',
#  'compile_date',
#  'compile_flags',
#  'cuda_devrt_library',
#  'cuda_include_path',
#  'cxx_compiler',
#  'floating_point_precision',
#  'git_branch',
#  'git_sha1',
#  'gpu_api_version',
#  'gpu_enabled',
#  'gpu_platform',
#  'hpmc_built',
#  'install_dir',
#  'llvm_enabled',
#  'md_built',
#  'metal_built',
#  'mpcd_built',
#  'mpi_enabled',
#  'source_dir',
#  'tbb_enabled',
#  'version']

# %% [markdown]
# ## 25,100-mer

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.genfromtxt(fname='/Users/stephaniemccallum/Desktop/cmelab/scratch/pps-melts/f279afbae7a955945fafb6e14c21a787/log.txt', skip_header=True)
plt.xlabel('time step')
plt.ylabel('energy')

plt.plot(data[500:,0], data[500:,3], linestyle='-', marker='*', label='PE()')

# %% [markdown]
# ## 50, 50-mers

# %%
data = np.genfromtxt(fname='/Users/stephaniemccallum/Desktop/cmelab/scratch/pps-melts/workspace/3cd661b3ad8700ae4df1fe0a279e93e3/log.txt', skip_header=True)
plt.xlabel('time step')
plt.ylabel('energy')

plt.plot(data[500:,0], data[500:,3], linestyle='-', marker='*', label='PE()')

# %%
# !head '/Users/stephaniemccallum/Desktop/cmelab/scratch/pps-melts/f279afbae7a955945fafb6e14c21a787/log.txt'
# Out:
# flowermd.base.simulation.Simulation.timestep flowermd.base.simulation.Simulation.tps md.compute.ThermodynamicQuantities.kinetic_temperature md.compute.ThermodynamicQuantities.potential_energy md.compute.ThermodynamicQuantities.kinetic_energy md.compute.ThermodynamicQuantities.volume md.compute.ThermodynamicQuantities.pressure md.pair.LJ.energy md.special_pair.LJ.energy md.bond.Harmonic.energy md.angle.Harmonic.energy md.dihedral.OPLS.energy
#                      0                                       0.00000                                        4.15132                                             9.32934e+05                                        1.08966e+05                                   5.39766e+06                                  0.01346                     -3.24457e+03           3.00997e+04              1.35246e+03             7.35717e+05              1.69010e+05
# ...
